# %% [markdown]
# ## Leitura e importação de registros

# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
path = '/content/gdrive/MyDrive/Colab Notebooks/CREDIT_CLUSTER/CREDIT.csv'
df = pd.read_csv(path)

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df.tail()
# Out:
#      CUST_ID     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 8945  C19186   28.493517           1.000000     291.12              0.00
# 8946  C19187   19.183215           1.000000     300.00              0.00
# 8947  C19188   23.398673           0.833333     144.40              0.00
# 8948  C19189   13.457564           0.833333       0.00              0.00
# 8949  C19190  372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 8945                    0.000000                          0.833333
# ...

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df['CREDIT_LIMIT'] = df['CREDIT_LIMIT'].fillna(df['CREDIT_LIMIT'].median())
df = df.drop(['CUST_ID', 'TENURE', 'MINIMUM_PAYMENTS'], axis = 1)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Visualização de dados

# %%
df.describe().T
# Out:
#                                    count         mean          std   min  \
# BALANCE                           8950.0  1564.474828  2081.531879   0.0
# BALANCE_FREQUENCY                 8950.0     0.877271     0.236904   0.0
# PURCHASES                         8950.0  1003.204834  2136.634782   0.0
# ONEOFF_PURCHASES                  8950.0   592.437371  1659.887917   0.0
# INSTALLMENTS_PURCHASES            8950.0   411.067645   904.338115   0.0
# CASH_ADVANCE                      8950.0   978.871112  2097.163877   0.0
# PURCHASES_FREQUENCY               8950.0     0.490351     0.401371   0.0
# ONEOFF_PURCHASES_FREQUENCY        8950.0     0.202458     0.298336   0.0
# PURCHASES_INSTALLMENTS_FREQUENCY  8950.0     0.364437     0.397448   0.0
# CASH_ADVANCE_FREQUENCY            8950.0     0.135144     0.200121   0.0
# CASH_ADVANCE_TRX                  8950.0     3.248827     6.824647   0.0
# PURCHASES_TRX                     8950.0    14.709832    24.857649   0.0
# ...

# %%
df.plot.box(subplots=True, layout=(3,5), figsize=(20, 20), sharey=False)
plt.show();

# %% [markdown]
# Avaliando o gráfico acima, percebemos que certos atributos do nosso dataframe estão fora da tipagem comum que desejamos utilizar no modelo, especificamente e mais abstrato, precisamos escalonar para que todas a features do dataframe se conversem.
#
# Outras observações interessantes são relacionadas ao limite de crédito, vamos investigar mais de perto essa feature e entender se existe uma causa de aumento de limite em relação as outras colunas da tabela. Porém, de certo sabemos que nosso dataframe inclui alguns outliers que caminham bem distante das congruências que queremos trazer na análise, mas iremos nos debruçar já já sobre esses efeitos.
